# %% [markdown]
# # Task 4 — Open-set recognition
#
# Select a GPU runtime, upload the updated `task4_colab.zip`, then run the first cell and authorize Google Drive. Training will not start if Drive authentication fails.
#
# Checkpoints save after each epoch to `MyDrive/ATML_PA1/task4_results/`. To resume after a runtime ends, upload the same ZIP into a new GPU notebook and rerun with the same Drive account. Completed methods are skipped. Do not run two notebooks against the same folder.
#
# Vanilla: 100 epochs; GCSC: 100; PROSER: 50. The report ZIP downloads automatically at completion and is also saved to Drive. The last cell downloads a full backup.

# %%
import zipfile
import runpy

# extract the standalone task 4 code
with zipfile.ZipFile('/content/task4_colab.zip') as archive:
    archive.extractall('/content/ATML_task4')

# run all required task 4 experiments and prepare the result archives
_ = runpy.run_path(
    '/content/ATML_task4/task4/scripts/colab_task4.py',
    run_name='__main__',
)

# %% [markdown]
# ## Download the full backup after completion
# Keep both ZIPs locally for your report and reproducibility.

# %%
from google.colab import files

# preserve weights, cached outputs, and the exact experiment source
files.download('/content/task4_full_backup.zip')
